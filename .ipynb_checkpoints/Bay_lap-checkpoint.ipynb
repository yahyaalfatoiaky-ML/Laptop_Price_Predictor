# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('laptops.csv')
df.head()
# Out:
#                                                 name   brand    price  \
# 0  Lenovo IdeaPad Slim 3 83K100CJIN Laptop (13th ...  Lenovo  67990.0
# 1  Asus Vivobook 14 S3407CA-LY084WS Laptop (Intel...    Asus  82990.0
# 2  Acer Aspire Lite AL15-52H Laptop (12th Gen Cor...    Acer  36541.0
# 3  HP Victus 15-fb3012AX Gaming Laptop (AMD Ryzen...      HP  65990.0
# 4  Apple MacBook Air 2022 Laptop (Apple M2/ 16GB/...   Apple  66990.0
#
#    ratings  specs_score             os                      processor  \
# 0     4.20         55.0  Windows 11 OS  13th Gen Intel Core i7 13620H
# 1     4.55         68.0  Windows 11 OS        Intel Core Ultra 7 255H
# 2     4.75         56.0  Windows 11 OS  12th Gen Intel Core i5 12450H
# 3     4.10         72.0  Windows 11 OS     8th Gen AMD Ryzen 5 8645HS
# 4     4.15          NaN         Mac OS                       Apple M2
#
#                         ram     storage                       graphics  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1011 entries, 0 to 1010
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         1011 non-null   object
#  1   brand        1011 non-null   object
#  2   price        1011 non-null   float64
#  3   ratings      1011 non-null   float64
#  4   specs_score  819 non-null    float64
#  5   os           1007 non-null   object
#  6   processor    1011 non-null   object
#  7   ram          1011 non-null   object
#  8   storage      1011 non-null   object
#  9   graphics     1011 non-null   object
#  10  screen_size  1011 non-null   object
#  11  resoultion   987 non-null    object
#  12  cores        1011 non-null   object
#  13  threads      921 non-null    object
#  14  warranty     1006 non-null   object
#  15  image_url    1011 non-null   object
# dtypes: float64(3), object(13)
# memory usage: 126.5+ KB

# %%
df.tail()
# Out:
#                                                    name    brand    price  \
# 1006  Infinix INBook X1 Slim XL21 Laptop (10th Gen C...  Infinix  45599.0
# 1007  HP 240 G8 Business Laptop (11th Gen Core i5/ 8...       HP  49990.0
# 1008  HP Pavilion 14-dv2041TU Laptop (12th Gen Core ...       HP  59480.0
# 1009  HP Pavilion 14-dv2015TU Laptop (12th Gen Core ...       HP  78850.0
# 1010  Asus TUF Gaming F15 FX506LHB-HN355WS Gaming La...     Asus  59500.0
#
#       ratings  specs_score              os                       processor  \
# 1006     4.60          NaN   Windows 11 OS   10th Gen Intel Core i5 1035G1
# 1007     4.65          NaN          DOS OS  11th Gen Intel Core i5 1135G7
# 1008     4.45         60.0   Windows 11 OS    12th Gen Intel Core i5 1235U
# 1009     4.60         63.0   Windows 11 OS    12th Gen Intel Core i7 1255U
# 1010     4.30         57.0  Windows 11  OS   10th Gen Intel Core i5 10300H
#
#                    ram     storage                       graphics  \
# ...

# %%
df.shape
# Out:
# (1011, 16)

# %%
df.describe()
# Out:
#                price      ratings  specs_score
# count    1011.000000  1011.000000   819.000000
# mean    83024.559842     4.370722    60.647131
# std     68509.395054     0.231190     7.332566
# min      9999.000000     4.000000    50.000000
# 25%     43020.000000     4.150000    54.000000
# 50%     64900.000000     4.350000    60.000000
# 75%     91990.000000     4.550000    66.000000
# max    617990.000000     4.750000    79.000000

# %%
df.isnull()
# Out:
#        name  brand  price  ratings  specs_score     os  processor    ram  \
# 0     False  False  False    False        False  False      False  False
# 1     False  False  False    False        False  False      False  False
# 2     False  False  False    False        False  False      False  False
# 3     False  False  False    False        False  False      False  False
# 4     False  False  False    False         True  False      False  False
# ...     ...    ...    ...      ...          ...    ...        ...    ...
# 1006  False  False  False    False         True  False      False  False
# 1007  False  False  False    False         True  False      False  False
# 1008  False  False  False    False        False  False      False  False
# 1009  False  False  False    False        False  False      False  False
# 1010  False  False  False    False        False  False      False  False
#
#       storage  graphics  screen_size  resoultion  cores  threads  warranty  \
# ...

# %%
df.dropna(inplace=True)
df.head()
# Out:
#                                                 name   brand    price  \
# 0  Lenovo IdeaPad Slim 3 83K100CJIN Laptop (13th ...  Lenovo  67990.0
# 1  Asus Vivobook 14 S3407CA-LY084WS Laptop (Intel...    Asus  82990.0
# 2  Acer Aspire Lite AL15-52H Laptop (12th Gen Cor...    Acer  36541.0
# 3  HP Victus 15-fb3012AX Gaming Laptop (AMD Ryzen...      HP  65990.0
# 5  Lenovo V15 G4 ‎82C70081GE Laptop (AMD Ryzen 5 ...  Lenovo  35490.0
#
#    ratings  specs_score             os                      processor  \
# 0     4.20         55.0  Windows 11 OS  13th Gen Intel Core i7 13620H
# 1     4.55         68.0  Windows 11 OS        Intel Core Ultra 7 255H
# 2     4.75         56.0  Windows 11 OS  12th Gen Intel Core i5 12450H
# 3     4.10         72.0  Windows 11 OS     8th Gen AMD Ryzen 5 8645HS
# 5     4.35         61.0  Windows 11 OS      7th Gen AMD Ryzen 5 7520U
#
#                 ram     storage                             graphics  \
# ...

# %%
df.shape
# Out:
# (764, 16)

# %%
df.fillna(0, inplace=True)

# %%
df.head()
# Out:
#                                                 name   brand    price  \
# 0  Lenovo IdeaPad Slim 3 83K100CJIN Laptop (13th ...  Lenovo  67990.0
# 1  Asus Vivobook 14 S3407CA-LY084WS Laptop (Intel...    Asus  82990.0
# 2  Acer Aspire Lite AL15-52H Laptop (12th Gen Cor...    Acer  36541.0
# 3  HP Victus 15-fb3012AX Gaming Laptop (AMD Ryzen...      HP  65990.0
# 5  Lenovo V15 G4 ‎82C70081GE Laptop (AMD Ryzen 5 ...  Lenovo  35490.0
#
#    ratings  specs_score             os                      processor  \
# 0     4.20         55.0  Windows 11 OS  13th Gen Intel Core i7 13620H
# 1     4.55         68.0  Windows 11 OS        Intel Core Ultra 7 255H
# 2     4.75         56.0  Windows 11 OS  12th Gen Intel Core i5 12450H
# 3     4.10         72.0  Windows 11 OS     8th Gen AMD Ryzen 5 8645HS
# 5     4.35         61.0  Windows 11 OS      7th Gen AMD Ryzen 5 7520U
#
#                 ram     storage                             graphics  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 764 entries, 0 to 1010
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         764 non-null    object
#  1   brand        764 non-null    object
#  2   price        764 non-null    float64
#  3   ratings      764 non-null    float64
#  4   specs_score  764 non-null    float64
#  5   os           764 non-null    object
#  6   processor    764 non-null    object
#  7   ram          764 non-null    object
#  8   storage      764 non-null    object
#  9   graphics     764 non-null    object
#  10  screen_size  764 non-null    object
#  11  resoultion   764 non-null    object
#  12  cores        764 non-null    object
#  13  threads      764 non-null    object
#  14  warranty     764 non-null    object
#  15  image_url    764 non-null    object
# dtypes: float64(3), object(13)
# memory usage: 101.5+ KB

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 5       False
#         ...
# 1004    False
# 1005    False
# 1008    False
# 1009    False
# 1010    False
# Length: 764, dtype: bool

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (756, 16)

# %%
df.head()
# Out:
#                                                 name   brand    price  \
# 0  Lenovo IdeaPad Slim 3 83K100CJIN Laptop (13th ...  Lenovo  67990.0
# 1  Asus Vivobook 14 S3407CA-LY084WS Laptop (Intel...    Asus  82990.0
# 2  Acer Aspire Lite AL15-52H Laptop (12th Gen Cor...    Acer  36541.0
# 3  HP Victus 15-fb3012AX Gaming Laptop (AMD Ryzen...      HP  65990.0
# 5  Lenovo V15 G4 ‎82C70081GE Laptop (AMD Ryzen 5 ...  Lenovo  35490.0
#
#    ratings  specs_score             os                      processor  \
# 0     4.20         55.0  Windows 11 OS  13th Gen Intel Core i7 13620H
# 1     4.55         68.0  Windows 11 OS        Intel Core Ultra 7 255H
# 2     4.75         56.0  Windows 11 OS  12th Gen Intel Core i5 12450H
# 3     4.10         72.0  Windows 11 OS     8th Gen AMD Ryzen 5 8645HS
# 5     4.35         61.0  Windows 11 OS      7th Gen AMD Ryzen 5 7520U
#
#                 ram     storage                             graphics  \
# ...

# %%
df = df.drop(columns=["name"])

# %%
df = df.drop(columns=["image_url"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 756 entries, 0 to 1010
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   brand        756 non-null    object
#  1   price        756 non-null    float64
#  2   ratings      756 non-null    float64
#  3   specs_score  756 non-null    float64
#  4   os           756 non-null    object
#  5   processor    756 non-null    object
#  6   ram          756 non-null    object
#  7   storage      756 non-null    object
#  8   graphics     756 non-null    object
#  9   screen_size  756 non-null    object
#  10  resoultion   756 non-null    object
#  11  cores        756 non-null    object
#  12  threads      756 non-null    object
#  13  warranty     756 non-null    object
# dtypes: float64(3), object(11)
# memory usage: 88.6+ KB

# %%
df["brand"].value_counts()
# Out:
# brand
# HP           197
# Lenovo       170
# Asus         130
# Acer         106
# MSI           66
# Dell          40
# Samsung       13
# Infinix       12
# Gigabyte       6
# Motorola       5
# Alienware      2
# Ultimus        2
# Thomson        2
# Zebronics      1
# ASUS           1
# Colorful       1
# Avita          1
# Wings          1
# Name: count, dtype: int64

# %%
brand = df["brand"].value_counts()
brand = brand[brand < 7].index
df = df[~df["brand"].isin(brand)]
df["brand"].value_counts()
# Out:
# brand
# HP         197
# Lenovo     170
# Asus       130
# Acer       106
# MSI         66
# Dell        40
# Samsung     13
# Infinix     12
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(df["price"])
plt.show()

# %%
Q1 = df["price"].quantile(0.25)
Q3 = df["price"].quantile(0.75)
IQR = Q3 - Q1
outliers = df[(df["price"] < Q1 - 1.5 * IQR) | (df["price"] > Q3 + 1.5 * IQR)]
print(outliers)
# Out:
#         brand     price  ratings  specs_score             os  \
# 64     Lenovo  137490.0     4.75         70.0  Windows 11 OS
# 72        MSI  149990.0     4.15         79.0  Windows 11 OS
# 94         HP  184999.0     4.65         74.0  Windows 11 OS
# 116        HP  137990.0     4.10         78.0  Windows 11 OS
# 119      Asus  139990.0     4.25         79.0  Windows 11 OS
# 161       MSI  140392.0     4.05         72.0  Windows 11 OS
# 187      Acer  164999.0     4.40         77.0  Windows 11 OS
# 200      Asus  139990.0     4.55         71.0  Windows 11 OS
# 211      Asus  219990.0     4.05         75.0  Windows 11 OS
# 261       MSI  134990.0     4.55         79.0  Windows 11 OS
# 284       MSI  134990.0     4.25         71.0  Windows 11 OS
# 294        HP  172550.0     4.05         79.0  Windows 11 OS
# 309        HP  201600.0     4.70         75.0  Windows 11 OS
# 336    Lenovo  230490.0     4.20         71.0  Windows 11 OS
# ...

# %%
median_price = df["price"].median()
df.loc[(df["price"] < Q1 - 1.5 * IQR) | (df["price"] > Q3 + 1.5 * IQR), "price"] = median_price

# %%
df.head()
# Out:
#     brand    price  ratings  specs_score             os  \
# 0  Lenovo  67990.0     4.20         55.0  Windows 11 OS
# 1    Asus  82990.0     4.55         68.0  Windows 11 OS
# 2    Acer  36541.0     4.75         56.0  Windows 11 OS
# 3      HP  65990.0     4.10         72.0  Windows 11 OS
# 5  Lenovo  35490.0     4.35         61.0  Windows 11 OS
#
#                        processor               ram     storage  \
# 0  13th Gen Intel Core i7 13620H  16 GB LPDDR5 RAM  512 GB SSD
# 1        Intel Core Ultra 7 255H    16 GB DDR5 RAM  512 GB SSD
# 2  12th Gen Intel Core i5 12450H    16 GB DDR4 RAM  512 GB SSD
# 3     8th Gen AMD Ryzen 5 8645HS    16 GB DDR5 RAM  512 GB SSD
# 5      7th Gen AMD Ryzen 5 7520U    16 GB DDR5 RAM  512 GB SSD
#
#                               graphics   screen_size          resoultion  \
# 0        Integrated Intel UHD Graphics  15.28 inches  1920 x 1080 pixels
# 1               Intel Integrated Intel     14 inches  1920 x 1200 pixels
# ...

# %%
df["resoultion"].unique()
df["resoultion"] = df["resoultion"].str.extract(r"(\d+)").astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 734 entries, 0 to 1010
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   brand        734 non-null    object
#  1   price        734 non-null    float64
#  2   ratings      734 non-null    float64
#  3   specs_score  734 non-null    float64
#  4   os           734 non-null    object
#  5   processor    734 non-null    object
#  6   ram          734 non-null    object
#  7   storage      734 non-null    object
#  8   graphics     734 non-null    object
#  9   screen_size  734 non-null    object
#  10  resoultion   734 non-null    int64
#  11  cores        734 non-null    object
#  12  threads      734 non-null    object
#  13  warranty     734 non-null    object
# dtypes: float64(3), int64(1), object(10)
# memory usage: 86.0+ KB

# %%
df["ram"] = df["ram"].str.extract(r"(\d+)").astype(int)
df["ram"].value_counts()
# Out:
# ram
# 16    513
# 8     157
# 32     34
# 24     19
# 12     11
# Name: count, dtype: int64

# %%
df["ram"].tail()
# Out:
# 1004    16
# 1005    16
# 1008    16
# 1009    16
# 1010     8
# Name: ram, dtype: int64

# %%
df["storage"] = df["storage"].str.extract(r"(\d+)").astype(int)
df["screen_size"] = df["screen_size"].str.extract(r"(\d+)").astype(float)
df["threads"] = df["threads"].str.extract(r"(\d+)").astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 734 entries, 0 to 1010
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   brand        734 non-null    object
#  1   price        734 non-null    float64
#  2   ratings      734 non-null    float64
#  3   specs_score  734 non-null    float64
#  4   os           734 non-null    object
#  5   processor    734 non-null    object
#  6   ram          734 non-null    int64
#  7   storage      734 non-null    int64
#  8   graphics     734 non-null    object
#  9   screen_size  734 non-null    float64
#  10  resoultion   734 non-null    int64
#  11  cores        734 non-null    object
#  12  threads      734 non-null    float64
#  13  warranty     734 non-null    object
# dtypes: float64(5), int64(3), object(6)
# memory usage: 86.0+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 734 entries, 0 to 1010
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   brand        734 non-null    object
#  1   price        734 non-null    float64
#  2   ratings      734 non-null    float64
#  3   specs_score  734 non-null    float64
#  4   os           734 non-null    object
#  5   processor    734 non-null    object
#  6   ram          734 non-null    int64
#  7   storage      734 non-null    int64
#  8   graphics     734 non-null    object
#  9   screen_size  734 non-null    float64
#  10  resoultion   734 non-null    int64
#  11  cores        734 non-null    object
#  12  threads      734 non-null    float64
#  13  warranty     734 non-null    object
# dtypes: float64(5), int64(3), object(6)
# memory usage: 86.0+ KB

# %%
df.head()
# Out:
#     brand    price  ratings  specs_score             os  \
# 0  Lenovo  67990.0     4.20         55.0  Windows 11 OS
# 1    Asus  82990.0     4.55         68.0  Windows 11 OS
# 2    Acer  36541.0     4.75         56.0  Windows 11 OS
# 3      HP  65990.0     4.10         72.0  Windows 11 OS
# 5  Lenovo  35490.0     4.35         61.0  Windows 11 OS
#
#                        processor  ram  storage  \
# 0  13th Gen Intel Core i7 13620H   16      512
# 1        Intel Core Ultra 7 255H   16      512
# 2  12th Gen Intel Core i5 12450H   16      512
# 3     8th Gen AMD Ryzen 5 8645HS   16      512
# 5      7th Gen AMD Ryzen 5 7520U   16      512
#
#                               graphics  screen_size  resoultion  \
# 0        Integrated Intel UHD Graphics         15.0        1920
# 1               Intel Integrated Intel         14.0        1920
# 2                   Intel UHD Graphics         15.0        1920
# 3         6 GB NVIDIA GeForce RTX 3050         15.0        1920
# ...

# %%
df["os"] = df["os"].str.extract(r"(\d+)").astype(float)
df["processor"] = df["processor"].str.extract(r"(\d+)").astype(int)
df["warranty"] = df["warranty"].str.extract(r"(\d+)").astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 734 entries, 0 to 1010
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   brand        734 non-null    object
#  1   price        734 non-null    float64
#  2   ratings      734 non-null    float64
#  3   specs_score  734 non-null    float64
#  4   os           717 non-null    float64
#  5   processor    734 non-null    int64
#  6   ram          734 non-null    int64
#  7   storage      734 non-null    int64
#  8   graphics     734 non-null    object
#  9   screen_size  734 non-null    float64
#  10  resoultion   734 non-null    int64
#  11  cores        734 non-null    object
#  12  threads      734 non-null    float64
#  13  warranty     730 non-null    float64
# dtypes: float64(7), int64(4), object(3)
# memory usage: 86.0+ KB

# %%
df.head()
# Out:
#     brand    price  ratings  specs_score    os  processor  ram  storage  \
# 0  Lenovo  67990.0     4.20         55.0  11.0         13   16      512
# 1    Asus  82990.0     4.55         68.0  11.0          7   16      512
# 2    Acer  36541.0     4.75         56.0  11.0         12   16      512
# 3      HP  65990.0     4.10         72.0  11.0          8   16      512
# 5  Lenovo  35490.0     4.35         61.0  11.0          7   16      512
#
#                               graphics  screen_size  resoultion  \
# 0        Integrated Intel UHD Graphics         15.0        1920
# 1               Intel Integrated Intel         14.0        1920
# 2                   Intel UHD Graphics         15.0        1920
# 3         6 GB NVIDIA GeForce RTX 3050         15.0        1920
# 5  Integrated AMD Radeon 610M Graphics         15.0        1920
#
#                         cores  threads  warranty
# 0          10 Cores (6P + 4E)     16.0       1.0
# ...

# %%
plt.figure(figsize=(10, 6))
plt.hist(df["price"], bins=30, edgecolor='black')
plt.title("Distribution of Laptop Prices")
plt.xlabel("Price")
plt.ylabel("Count")
plt.show()

# %%
plt.scatter(df["ram"], df["price"])
plt.title("RAM vs Price")
plt.xlabel("RAM (GB)")
plt.ylabel("Price")
plt.show()

# %%
plt.scatter(df["storage"], df["price"])
plt.title("Storage vs Price")
plt.xlabel("Storage (GB)")
plt.ylabel("Price")
plt.show()

# %%
plt.scatter(df["brand"], df["price"])
plt.title("Brand vs Price")
plt.xlabel("Brand")
plt.ylabel("Price")
plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#                 price   ratings  specs_score        os  processor       ram  \
# price        1.000000  0.017153     0.611289 -0.020566   0.025116  0.475592
# ratings      0.017153  1.000000     0.012386 -0.050617  -0.002957  0.053766
# specs_score  0.611289  0.012386     1.000000  0.036283  -0.009801  0.486499
# os          -0.020566 -0.050617     0.036283  1.000000   0.013391 -0.005790
# processor    0.025116 -0.002957    -0.009801  0.013391   1.000000 -0.001678
# ram          0.475592  0.053766     0.486499 -0.005790  -0.001678  1.000000
# storage     -0.397038 -0.025205    -0.497369 -0.022258  -0.029097 -0.404131
# screen_size  0.069563  0.038338     0.254329  0.052925  -0.054946  0.000948
# resoultion   0.256587  0.012041     0.373585  0.010598   0.043416  0.320041
# threads      0.548785  0.010554     0.608407 -0.004412   0.066436  0.357254
# warranty     0.179607 -0.011168     0.271665  0.009621   0.054854  0.095447
#
# ...

# %%
##.  Feature Engineering
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df["brand"] = le.fit_transform(df["brand"])
df.head()
# Out:
#    brand    price  ratings  specs_score    os  processor  ram  storage  \
# 0      5  67990.0     4.20         55.0  11.0         13   16      512
# 1      1  82990.0     4.55         68.0  11.0          7   16      512
# 2      0  36541.0     4.75         56.0  11.0         12   16      512
# 3      3  65990.0     4.10         72.0  11.0          8   16      512
# 5      5  35490.0     4.35         61.0  11.0          7   16      512
#
#                               graphics  screen_size  resoultion  \
# 0        Integrated Intel UHD Graphics         15.0        1920
# 1               Intel Integrated Intel         14.0        1920
# 2                   Intel UHD Graphics         15.0        1920
# 3         6 GB NVIDIA GeForce RTX 3050         15.0        1920
# 5  Integrated AMD Radeon 610M Graphics         15.0        1920
#
#                         cores  threads  warranty
# 0          10 Cores (6P + 4E)     16.0       1.0
# 1  16 Cores (6P + 8E + 2LP-E)     16.0       1.0
# ...

# %%
x = df.drop(columns=["price"])
y = df["price"]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
model.fit(x_train, y_train)
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
y_pred = model.predict(x_test)
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
print("R^2 Score:", r2_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/lf/rg1km_h52d3gp3b356zyw05m0000gn/T/ipykernel_46341/3677123501.py in ?()
#       1 from sklearn.ensemble import RandomForestRegressor
#       2 model = RandomForestRegressor()
# ----> 3 model.fit(x_train, y_train)
#       4 from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
#       5 y_pred = model.predict(x_test)
#       6 print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
#
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1332                 skip_parameter_validation=(
#    1333                     prefer_skip_nested_validation or global_skip_validation
#    1334                 )
#    1335             ):
# -> 1336                 return fit_method(estimator, *args, **kwargs)
#
# ...

# %%
df.head()
# Out:
#    brand    price  ratings  specs_score    os  processor  ram  storage  \
# 0      5  67990.0     4.20         55.0  11.0         13   16      512
# 1      1  82990.0     4.55         68.0  11.0          7   16      512
# 2      0  36541.0     4.75         56.0  11.0         12   16      512
# 3      3  65990.0     4.10         72.0  11.0          8   16      512
# 5      5  35490.0     4.35         61.0  11.0          7   16      512
#
#                               graphics  screen_size  resoultion  \
# 0        Integrated Intel UHD Graphics         15.0        1920
# 1               Intel Integrated Intel         14.0        1920
# 2                   Intel UHD Graphics         15.0        1920
# 3         6 GB NVIDIA GeForce RTX 3050         15.0        1920
# 5  Integrated AMD Radeon 610M Graphics         15.0        1920
#
#                         cores  threads  warranty
# 0          10 Cores (6P + 4E)     16.0       1.0
# 1  16 Cores (6P + 8E + 2LP-E)     16.0       1.0
# ...
